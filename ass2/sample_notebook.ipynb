# %% [markdown]
# # CITS5508 Assignment 2 - Sample Notebook
#
# This is a sample Jupyter notebook for Assignment 2.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd

print("Assignment 2 sample notebook!")

# %%
# Example data analysis
data = pd.DataFrame({
    "name": ["Alice", "Bob", "Charlie"],
    "score": [85, 92, 78]
})
data
